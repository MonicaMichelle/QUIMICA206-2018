# %%
f=open("elementos.txt")
texto=f.readlines()

for s in texto:
    cadena=s.replace("\t",",")
    cadena=cadena.replace(",,",",,")
    print(cadena)
texto

# %%
import requests

# %%
url="https://www.critica.com.pa/"
respuesta=requests.get(url)
respuesta.text
# Out:
# ' <script type="text/javascript">\n \n  if (screen.width <= 800) {\n    window.location = "//m.critica.com.pa/";\n  }\n \n</script>\n<!DOCTYPE html>\n<html lang="es" dir="ltr" class="no-js" xmlns:og="http://ogp.me/ns#" xmlns:article="http://ogp.me/ns/article#" xmlns:book="http://ogp.me/ns/book#" xmlns:profile="http://ogp.me/ns/profile#" xmlns:video="http://ogp.me/ns/video#" xmlns:product="http://ogp.me/ns/product#" xmlns:content="http://purl.org/rss/1.0/modules/content/" xmlns:dc="http://purl.org/dc/terms/" xmlns:foaf="http://xmlns.com/foaf/0.1/" xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#" xmlns:sioc="http://rdfs.org/sioc/ns#" xmlns:sioct="http://rdfs.org/sioc/types#" xmlns:skos="http://www.w3.org/2004/02/skos/core#" xmlns:xsd="http://www.w3.org/2001/XMLSchema#">\n<head profile="http://www.w3.org/1999/xhtml/vocab">\n\n<meta http-equiv="refresh" content="150" />\n<title>Critica | Noticias y Novedades de Panamá y el Mundo</title>\n<meta http-equiv="Content-Type" content="text/ht
# ...

# %%
from pandas import Series, DataFrame
import pandas as pd
import numpy as np

# %%
obj = Series([4, 7, -5, 3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj2 = Series([4, 7, -5, 3], index=['d', 'b', 'a', 'c'])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
obj2['b']
# Out:
# 7

# %%
obj2[obj2>0]
# Out:
# d    4
# b    7
# c    3
# dtype: int64

# %%
data = {'Panama': ['Chiriqui', 'colon', 'santiago', 'bocas del toro', 'los santos'],
'year': [2000, 2001, 2002, 2001, 2002],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9]}

frame = DataFrame(data)
frame
# Out:
#            Panama  year  pop
# 0        Chiriqui  2000  1.5
# 1           colon  2001  1.7
# 2        santiago  2002  3.6
# 3  bocas del toro  2001  2.4
# 4      los santos  2002  2.9

# %%
DataFrame(data, columns=['year', 'Panama', 'pop'])
# Out:
#    year          Panama  pop
# 0  2000        Chiriqui  1.5
# 1  2001           colon  1.7
# 2  2002        santiago  3.6
# 3  2001  bocas del toro  2.4
# 4  2002      los santos  2.9

# %%
frame2 = DataFrame(data, columns=['year', 'panama', 'pop', 'debt'],index=['one', 'two', 'three', 'four', 'five'])
frame2
# Out:
#        year panama  pop debt
# one    2000    NaN  1.5  NaN
# two    2001    NaN  1.7  NaN
# three  2002    NaN  3.6  NaN
# four   2001    NaN  2.4  NaN
# five   2002    NaN  2.9  NaN

# %%
frame2['debt'] = 16.5
frame2
# Out:
#        year panama  pop  debt
# one    2000    NaN  1.5  16.5
# two    2001    NaN  1.7  16.5
# three  2002    NaN  3.6  16.5
# four   2001    NaN  2.4  16.5
# five   2002    NaN  2.9  16.5

# %%
frame2['debt'] = np.arange(5.)
frame2
# Out:
#        year panama  pop  debt
# one    2000    NaN  1.5   0.0
# two    2001    NaN  1.7   1.0
# three  2002    NaN  3.6   2.0
# four   2001    NaN  2.4   3.0
# five   2002    NaN  2.9   4.0
